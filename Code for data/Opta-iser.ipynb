# %%
import pandas as pd

df = pd.read_csv("Downloads/Opta Matches/Women/DEN/AGF 3-0 Viborg.csv")
#df = pd.read_csv("Downloads/AZ 0-1 Sparta.csv")

type_cols = [col for col in df.columns if '/qualifierId' in col]

df['endX'] = 0.0
df['endY'] = 0.0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 140:
            endx = df1.loc[:,'qualifier/%i/value' %j].values[0]
            df['endX'][i] = endx
        else:
            j +=1
    k = 0
    for k in range(len(type_cols)):
        col = df1[type_cols[k]].values[0]
        if col == 141:
            endy = df1.loc[:,'qualifier/%i/value' %k].values[0]
            df['endY'][i] = endy
        else:
            k +=1

df['Cross'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 2:
            df['Cross'][i] = 1
        else:
            j +=1
           
df['Cutback'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 195:
            df['Cutback'][i] = 1
        else:
            j +=1

df['Corner'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 6:
            df['Corner'][i] = 1
        else:
            j +=1
           
df['FK'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 5:
            df['FK'][i] = 1
        else:
            j +=1
df['GK'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 124:
            df['GK'][i] = 1
        else:
            j +=1
df['ThrowIn'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 107:
            df['ThrowIn'][i] = 1
        else:
            j +=1

df['Throw-in set piece	'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 160:
            df['Throw-in set piece	'][i] = 1
        else:
            j +=1

df['Through-ball'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 4:
            df['Through-ball'][i] = 1
        else:
            j +=1

df['LongBall'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 1:
            df['LongBall'][i] = 1
        else:
            j +=1

df['Switch'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 196:
            df['Switch'][i] = 1
        else:
            j +=1
            
df['Assist'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 210:
            df['Assist'][i] = 1
        else:
            j +=1

df['2nd Assist'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 218:
            df['2nd Assist'][i] = 1
        else:
            j +=1

df['Number'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 59:
            df['Number'][i] = 1
        else:
            j +=1
            
df['FromCorner'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 25:
            df['FromCorner'][i] = 1
        else:
            j +=1

df['Keeper throw'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 123:
            df['Keeper throw'][i] = 1
        else:
            j +=1

df['GoalMouthY'] = 0.0
df['GoalMouthZ'] = 0.0
for i in range(len(df)):            
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 102:
            mouthy = df1.loc[:,'qualifier/%i/value' %j].values[0]
            df['GoalMouthY'][i] = mouthy
        else:
            j +=1
    k = 0
    for k in range(len(type_cols)):
        col = df1[type_cols[k]].values[0]
        if col == 103:
            mouthz = df1.loc[:,'qualifier/%i/value' %k].values[0]
            df['GoalMouthZ'][i] = mouthz
        else:
            k +=1

df['isOwnGoal'] = 0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 28:
            df['isOwnGoal'][i] = 1
        else:
            j +=1
           
df['pass_angle'] = 0.0
df['pass_length'] = 0.0
for i in range(len(df)):
    df1 = df.iloc[i:i+1,:]
    j = 0
    for j in range(len(type_cols)):
        col = df1[type_cols[j]].values[0]
        if col == 213:
            angle = df1.loc[:,'qualifier/%i/value' %j].values[0]
            df.pass_angle[i] = angle
        else:
            j +=1
    k = 0
    for k in range(len(type_cols)):
        col = df1[type_cols[k]].values[0]
        if col == 212:
            length = df1.loc[:,'qualifier/%i/value' %k].values[0]
            df.pass_length[i] = length
        else:
            k +=1

### Here's where you can now filter on typeId and player
#df = df[df['typeId']==1]
#df = df[df['playerName']=='Denzel Dumfries']

df.to_excel("DEN.xlsx")
# Out:
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['endX'][i] = endx
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['endY'][i] = endy
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cross'][i] = 1
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cutback'][i] = 1
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Corner'][i] = 1
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FK'][i] = 1
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:79: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GK'][i] = 1
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:89: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ThrowIn'][i] = 1
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:122: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['LongBall'][i] = 1
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Switch'][i] = 1
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Assist'][i] = 1
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:166: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Number'][i] = 1
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:177: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FromCorner'][i] = 1
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:188: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Keeper throw'][i] = 1
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:201: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GoalMouthY'][i] = mouthy
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:209: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GoalMouthZ'][i] = mouthz
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:233: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.pass_angle[i] = angle
# /var/folders/34/zddkb62n3590wbtcq5cfz3z40000gn/T/ipykernel_45620/1313668912.py:241: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.pass_length[i] = length

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from mplsoccer import Pitch

import pandas as pd
import numpy as np
from mplsoccer.pitch import VerticalPitch
import matplotlib.pyplot as plt
from mplsoccer import Pitch


df = pd.read_excel('Bayern 1-0 Hoffenheim.xlsx')

#df.x = df.x*1.2
#df.y = df.y*.8
#df.endX = df.endX*1.2
#df.endY = df.endY*1.2

df.head()

df['beginning'] = np.sqrt(np.square(120-df['x']) + np.square(40 - df['y']))
df['end'] = np.sqrt(np.square(120 - df['endX']) + np.square(40 - df['endY']))


df['progressive'] = [(df['end'][x]) / (df['beginning'][x]) < .75 for x in range(len(df.beginning))]

df = df.loc[df['typeId']==1]
#df = df.loc[df['TeamId']==1113]


#df.loc[df['progressive']==True].reset_index()
            
df.to_excel("Bayern 1-0 Hoffenheim.xlsx")
# Out:
# /Users/marclamberts/opt/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_excel("Bayern 1-0 Hoffenheim.xlsx")

# preprocess the dataframe so we only have the data we want
# We want to get it down to be only successful passes made by Bruno Penandes
# we can use pandas .loc method to achieve this with a bunch of & statements

#df = df.loc[(df['teamId']==212) & (df['playerId']==85470) & (df['outcomeType/displayName']=='Successful') & (df['type/displayName']=='Pass')]

#Import xT Grid, turn it into an array, and then get how many rows and columns it has
xT = pd.read_csv("xT_grid.csv", header=None)
xT = np.array(xT)
xT_rows, xT_cols = xT.shape
xT

print(xT_rows,xT_cols)

df['x1_bin'] = pd.cut(df['x'], bins=xT_cols, labels=False)
df['y1_bin'] = pd.cut(df['y'], bins=xT_rows, labels=False)
df['x2_bin'] = pd.cut(df['endX'], bins=xT_cols, labels=False)
df['y2_bin'] = pd.cut(df['endY'], bins=xT_rows, labels=False)

df['start_zone_value'] = df[['x1_bin', 'y1_bin']].apply(lambda x: xT[x[1]][x[0]], axis=1)
df['end_zone_value'] = df[['x2_bin', 'y2_bin']].apply(lambda x: xT[x[1]][x[0]], axis=1)

df['xT'] = df['end_zone_value'] - df['start_zone_value']

df.head()

df.to_excel("Bayern 1-0 Hoffenheim.xlsx")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 11>()
#       3 # preprocess the dataframe so we only have the data we want
#       4 # We want to get it down to be only successful passes made by Bruno Penandes
#       5 # we can use pandas .loc method to achieve this with a bunch of & statements
#    (...)
#       8
#       9 #Import xT Grid, turn it into an array, and then get how many rows and columns it has
#      10 xT = pd.read_csv("xT_grid.csv", header=None)
# ---> 11 xT = np.array(xT)
#      12 xT_rows, xT_cols = xT.shape
#      13 xT
#
# NameError: name 'np' is not defined

# %%
df.to_excel("DDpre.xlsx")
